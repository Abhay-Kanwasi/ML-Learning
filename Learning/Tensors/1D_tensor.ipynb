# %%
import numpy as np

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
print("1D Tensor (Vector):", arr)
# Out:
# 1D Tensor (Vector): [1 2 3 4 5]

# %%
print("Dimension of the tensor:", arr.ndim)
# Out:
# Dimension of the tensor: 1
